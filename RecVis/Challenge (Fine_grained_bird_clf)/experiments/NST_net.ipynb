# %%
# !git clone  https://github.com/kallel-mahdi/BIRD-NOT
# %cd BIRD-NOT/
# !gdown --id 1jxDltcr7Rt8KF-aJNnb04u8N-84U2ueG
# !unzip -qq mva-recvis-2020.zip
# !gdown --id 1L1G1yCA2ZyPWbn2SqFK0KkFoiv6y73Eu
# !unzip -qq bird_dataset_mix
# !gdown --id 1j0YHMZvFFrCTWmV1WFHgBGcTIhlx7Hj-
# !unzip -qq cub.zip
# In order to install the latest (beta) use
# !pip install git+https://github.com/pabloppp/pytorch-tools -U

# %%
# %cd /content/BIRD-NOT/
# !python main.py --epochs 30
# Out:
# /content/BIRD-NOT
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# 100% 97.8M/97.8M [00:00<00:00, 208MB/s]
# Using GPU
# To use this log_lamb_rs, please run 'pip install tensorboardx'. Also you must have Tensorboard running to see results
# Train Epoch: 1 [0/2164 (0%)]	Loss: 3.079042
# /usr/local/lib/python3.6/dist-packages/torchtools/optim/lookahead.py:42: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:882.)
#   slow.add_(group['lookahead_alpha'], fast_p.data - slow)
# Train Epoch: 1 [100/2164 (5%)]	Loss: 3.151323
# Train Epoch: 1 [200/2164 (9%)]	Loss: 3.305225
# Train Epoch: 1 [300/2164 (14%)]	Loss: 2.889578
# Train Epoch: 1 [400/2164 (19%)]	Loss: 2.884190
# ...

# %%
# !python evaluate.py --model /content/BIRD-NOT/experiment/model_30.pth
# Out:
# Using GPU
#
# Validation set: Average loss: 0.0648, Accuracy: 1884/2198 (86%)

# %%
# !python pseudo_label.py  --model experiment/model_30.pth
# Out:
# To use this log_lamb_rs, please run 'pip install tensorboardx'. Also you must have Tensorboard running to see results
# Using GPU
# ...
# Train Epoch: 31 [0/2164 (0%)]	Loss: 0.035760
# /usr/local/lib/python3.6/dist-packages/torchtools/optim/lookahead.py:42: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:882.)
#   slow.add_(group['lookahead_alpha'], fast_p.data - slow)
# Train Epoch: 31 [100/2164 (5%)]	Loss: 0.002165
# Train Epoch: 31 [200/2164 (9%)]	Loss: 0.030953
# Train Epoch: 31 [300/2164 (14%)]	Loss: 0.285455
# Train Epoch: 31 [400/2164 (19%)]	Loss: 0.000916
# Train Epoch: 31 [500/2164 (23%)]	Loss: 0.000401
# Train Epoch: 31 [600/2164 (28%)]	Loss: 0.001888
# Train Epoch: 31 [700/2164 (32%)]	Loss: 0.052514
# Train Epoch: 31 [800/2164 (37%)]	Loss: 0.012439
# ...

# %%
# !gdown --id 1uga6j9r1PWZMdZMCss9AHmopaajIiW5h
# !unzip -qq test_images.zip
# !python submission.py --data "/content/BIRD-NOT/test_images/" --model "/content/BIRD-NOT/experiment/model_30.pth"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1uga6j9r1PWZMdZMCss9AHmopaajIiW5h
# To: /content/BIRD-NOT/test_images.zip
# 64.6MB [00:00, 79.3MB/s]
# Using GPU
# 100% 517/517 [00:16<00:00, 30.80it/s]
# Succesfully wrote experiment/kaggle.csv, you can upload this file to the kaggle competition website

# %%
from google.colab import drive
drive.mount("/content/drive")

# !cp -r /content/BIRD-NOT/experiment/model_76.pth /content/drive/My\ Drive/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
